# %%
import pandas as pd

# %%
data =pd.read_csv("F:\\Dataset\\sales_data_final.csv")

# %%
df = data.copy()

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.sales)
# Out:
# pandas.core.series.Series

# %%
df.head(10)
# Out:
#           order_id order_date ship_date       ship_mode     customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class   Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class     Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class      Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 5    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 6     CA-2011-1510   1/2/2011  1/6/2011  Standard Class   Magdelene Morse
# 7    IN-2011-79397   1/3/2011  1/3/2011        Same Day       Kean Nguyen
# 8    ID-2011-80230   1/3/2011  1/9/2011  Standard Class      Ken Lonsdale
# 9     IZ-2011-4680   1/3/2011  1/7/2011  Standard Class  Lindsay Williams
#
#        segment            state      country  market   region  ...  \
# 0     Consumer      Constantine      Algeria  Africa   Africa  ...
# ...

# %%
df.tail(10)
# Out:
#              order_id  order_date ship_date       ship_mode  \
# 51280    TZ-2014-8220  12/31/2014  1/6/2015  Standard Class
# 51281  CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51282    UP-2014-4410  12/31/2014  1/4/2015  Standard Class
# 51283   IN-2014-23754  12/31/2014  1/7/2015  Standard Class
# 51284  MX-2014-108574  12/31/2014  1/4/2015  Standard Class
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#             customer_name      segment             state        country  \
# 51280  Christine Kargatis  Home Office     Dar Es Salaam       Tanzania
# 51281          Erica Bern    Corporate        California  United States
# 51282        Guy Thornton     Consumer      Zaporizhzhya        Ukraine
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.shape
# Out:
# (51290, 21)

# %%
df.size
# Out:
# 1077090

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.sample(10)
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 9050   ES-2012-3247635    1/4/2012    1/8/2012  Standard Class
# 4730      RS-2011-7040   8/30/2011   8/30/2011        Same Day
# 41883     UP-2014-7790    8/5/2014    8/8/2014    Second Class
# 38204   CA-2014-161774   5/15/2014   5/16/2014     First Class
# 24902  IT-2013-4744502   6/20/2013   6/27/2013  Standard Class
# 24678   CA-2013-107216   6/15/2013   6/18/2013     First Class
# 44694  ES-2014-1224526   9/20/2014   9/24/2014  Standard Class
# 51270    IN-2014-23754  12/31/2014    1/7/2015  Standard Class
# 46527   CA-2014-130211  10/23/2014  10/23/2014        Same Day
# 3198      SY-2011-8050   6/23/2011   6/28/2011  Standard Class
#
#           customer_name      segment            state         country market  \
# 9050   Theone Pippenger     Consumer          England  United Kingdom     EU
# 4730      Joe Kamberova     Consumer         Vladimir          Russia   EMEA
# ...

# %%
df.count()
# Out:
# order_id          51290
# order_date        51290
# ship_date         51290
# ship_mode         51290
# customer_name     51290
# segment           51290
# state             51290
# country           51290
# market            51290
# region            51290
# product_id        51290
# category          51290
# sub_category      51290
# product_name      51290
# sales             51290
# quantity          51290
# discount          51290
# profit            51290
# shipping_cost     51290
# order_priority    51290
# year              51290
# dtype: int64

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.describe(include="all").T
# Out:
#                   count unique              top   freq         mean  \
# order_id          51290  25035   CA-2014-100111     14          NaN
# order_date        51290   1430        6/18/2014    135          NaN
# ship_date         51290   1464       11/22/2014    130          NaN
# ship_mode         51290      4   Standard Class  30775          NaN
# customer_name     51290    795  Muhammed Yedwab    108          NaN
# segment           51290      3         Consumer  26518          NaN
# state             51290   1094       California   2001          NaN
# country           51290    147    United States   9994          NaN
# market            51290      7             APAC  11002          NaN
# region            51290     13          Central  11117          NaN
# product_id        51290  10292  OFF-AR-10003651     35          NaN
# category          51290      3  Office Supplies  31273          NaN
# sub_category      51290     17          Binders   6152          NaN
# ...

# %%
df[["category", "sales"]]
# Out:
#               category sales
# 0      Office Supplies   408
# 1      Office Supplies   120
# 2      Office Supplies    66
# 3      Office Supplies    45
# 4            Furniture   114
# ...                ...   ...
# 51285  Office Supplies    14
# 51286  Office Supplies     4
# 51287  Office Supplies    26
# 51288  Office Supplies     7
# 51289  Office Supplies     3
#
# [51290 rows x 2 columns]

# %%
df["sub_category"].value_counts()
# Out:
# sub_category
# Binders        6152
# Storage        5059
# Art            4883
# Paper          3538
# Chairs         3434
# Phones         3357
# Furnishings    3170
# Accessories    3075
# Labels         2606
# Envelopes      2435
# Supplies       2425
# Fasteners      2420
# Bookcases      2411
# Copiers        2223
# Appliances     1755
# Machines       1486
# Tables          861
# Name: count, dtype: int64

# %%
df.drop("order_id", axis = 1)
# Out:
#        order_date ship_date       ship_mode     customer_name      segment  \
# 0        1/1/2011  1/6/2011  Standard Class   Toby Braunhardt     Consumer
# 1        1/1/2011  1/8/2011  Standard Class       Joseph Holt     Consumer
# 2        1/1/2011  1/5/2011    Second Class     Annie Thurman     Consumer
# 3        1/1/2011  1/5/2011    Second Class      Eugene Moren  Home Office
# 4        1/1/2011  1/8/2011  Standard Class       Joseph Holt     Consumer
# ...           ...       ...             ...               ...          ...
# 51285  12/31/2014  1/4/2015  Standard Class        Erica Bern    Corporate
# 51286  12/31/2014  1/5/2015  Standard Class         Liz Preis     Consumer
# 51287  12/31/2014  1/2/2015    Second Class  Charlotte Melton     Consumer
# 51288  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen     Consumer
# 51289  12/31/2014  1/4/2015  Standard Class     Jill Matthias     Consumer
#
# ...

# %%
df.drop("order_id", axis=1, inplace = True)

# %%
df
# Out:
#        order_date ship_date       ship_mode     customer_name      segment  \
# 0        1/1/2011  1/6/2011  Standard Class   Toby Braunhardt     Consumer
# 1        1/1/2011  1/8/2011  Standard Class       Joseph Holt     Consumer
# 2        1/1/2011  1/5/2011    Second Class     Annie Thurman     Consumer
# 3        1/1/2011  1/5/2011    Second Class      Eugene Moren  Home Office
# 4        1/1/2011  1/8/2011  Standard Class       Joseph Holt     Consumer
# ...           ...       ...             ...               ...          ...
# 51285  12/31/2014  1/4/2015  Standard Class        Erica Bern    Corporate
# 51286  12/31/2014  1/5/2015  Standard Class         Liz Preis     Consumer
# 51287  12/31/2014  1/2/2015    Second Class  Charlotte Melton     Consumer
# 51288  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen     Consumer
# 51289  12/31/2014  1/4/2015  Standard Class     Jill Matthias     Consumer
#
# ...

# %%
df.drop_duplicates()
# Out:
#        order_date ship_date       ship_mode     customer_name      segment  \
# 0        1/1/2011  1/6/2011  Standard Class   Toby Braunhardt     Consumer
# 1        1/1/2011  1/8/2011  Standard Class       Joseph Holt     Consumer
# 2        1/1/2011  1/5/2011    Second Class     Annie Thurman     Consumer
# 3        1/1/2011  1/5/2011    Second Class      Eugene Moren  Home Office
# 4        1/1/2011  1/8/2011  Standard Class       Joseph Holt     Consumer
# ...           ...       ...             ...               ...          ...
# 51285  12/31/2014  1/4/2015  Standard Class        Erica Bern    Corporate
# 51286  12/31/2014  1/5/2015  Standard Class         Liz Preis     Consumer
# 51287  12/31/2014  1/2/2015    Second Class  Charlotte Melton     Consumer
# 51288  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen     Consumer
# 51289  12/31/2014  1/4/2015  Standard Class     Jill Matthias     Consumer
#
# ...

# %%
df.loc[0:50000:10000, ["state", "sales"]]
# Out:
#                               state sales
# 0                       Constantine   408
# 10000  Australian Capital Territory   209
# 20000                       England   164
# 30000                  Minas Gerais   220
# 40000              Santiago de Cuba    35
# 50000                 Pinar del R¡o   150

# %%
df.iloc[0:51000:10000, 0:22:4]
# Out:
#        order_date      segment     region  \
# 0        1/1/2011     Consumer     Africa
# 10000    3/2/2012  Home Office    Oceania
# 20000    1/2/2013    Corporate      North
# 30000  10/16/2013    Corporate      South
# 40000   6/20/2014    Corporate  Caribbean
# 50000  12/12/2014  Home Office  Caribbean
#
#                                   product_name   profit
# 0                          Tenex Lockers, Blue  106.140
# 10000  Green Bar Cards & Envelopes, Multicolor -108.150
# 20000     GlobeWeis Manila Envelope, Set of 50   54.180
# 30000             Dania Classic Bookcase, Pine -126.408
# 40000           Ibico Binding Machine, Durable    0.340
# 50000        Xerox Cards & Envelopes, Recycled   68.800

# %%
df
# Out:
#        order_date ship_date       ship_mode     customer_name      segment  \
# 0        1/1/2011  1/6/2011  Standard Class   Toby Braunhardt     Consumer
# 1        1/1/2011  1/8/2011  Standard Class       Joseph Holt     Consumer
# 2        1/1/2011  1/5/2011    Second Class     Annie Thurman     Consumer
# 3        1/1/2011  1/5/2011    Second Class      Eugene Moren  Home Office
# 4        1/1/2011  1/8/2011  Standard Class       Joseph Holt     Consumer
# ...           ...       ...             ...               ...          ...
# 51285  12/31/2014  1/4/2015  Standard Class        Erica Bern    Corporate
# 51286  12/31/2014  1/5/2015  Standard Class         Liz Preis     Consumer
# 51287  12/31/2014  1/2/2015    Second Class  Charlotte Melton     Consumer
# 51288  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen     Consumer
# 51289  12/31/2014  1/4/2015  Standard Class     Jill Matthias     Consumer
#
# ...
